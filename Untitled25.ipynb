# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')
 
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

url = "https://raw.githubusercontent.com/jbagnato/machine-learning/master/time_series.csv"

df = pd.read_csv(url, parse_dates=[0], header=None,index_col=0, squeeze=True,names=['fecha','unidades'])
df.head()
# Out:
# fecha
# 2017-01-02    236
# 2017-01-03    237
# 2017-01-04    290
# 2017-01-05    221
# 2017-01-07    128
# Name: unidades, dtype: int64

# %%
# Por ejemplo, podemos ver de qué fechas tenemos datos con:
print(df.index.min())
print(df.index.max())
# Out:
# 2017-01-02 00:00:00
# 2018-11-30 00:00:00

# %%
# Y ahora veamos cuantas muestras tenemos de cada año:
print(len(df['2017']))
print(len(df['2018']))
# Out:
# 315
# 289

# %%
df.describe()
# Out:
# count    604.000000
# mean     215.935430
# std       75.050304
# min       51.000000
# 25%      171.000000
# 50%      214.000000
# 75%      261.250000
# max      591.000000
# Name: unidades, dtype: float64

# %%
# De hecho aprovechemos el tener indice de fechas con pandas y saquemos los promedios mensuales:
meses =df.resample('M').mean()
meses
# Out:
# fecha
# 2017-01-31    203.923077
# 2017-02-28    184.666667
# 2017-03-31    182.964286
# 2017-04-30    198.960000
# 2017-05-31    201.185185
# 2017-06-30    209.518519
# 2017-07-31    278.923077
# 2017-08-31    316.000000
# 2017-09-30    222.925926
# 2017-10-31    207.851852
# 2017-11-30    185.925926
# 2017-12-31    213.200000
# 2018-01-31    201.384615
# 2018-02-28    190.625000
# 2018-03-31    174.846154
# 2018-04-30    186.000000
# 2018-05-31    190.666667
# 2018-06-30    196.037037
# 2018-07-31    289.500000
# 2018-08-31    309.038462
# 2018-09-30    230.518519
# 2018-10-31    209.444444
# 2018-11-30    184.481481
# Freq: M, Name: unidades, dtype: float64

# %%
# Y visualicemos esas medias mensuales:
# Azul : 2017
# Naraja : 2018
plt.plot(meses['2017'].values)
plt.plot(meses['2018'].values)

# %%
# Veamos la gráfica de ventas diarias (en unidades) en junio y julio
verano2017 = df['2017-06-01':'2017-09-01']
plt.plot(verano2017.values)
verano2018 = df['2018-06-01':'2018-09-01']
plt.plot(verano2018.values)

# %%
# Analizamos 7 dias y supondremos el 8
PASOS=7

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7   -0.314815  -0.311111  -0.114815  -0.370370  -0.714815  -0.103704
# 8   -0.311111  -0.114815  -0.370370  -0.714815  -0.103704  -0.225926
# 9   -0.114815  -0.370370  -0.714815  -0.103704  -0.225926  -0.433333
# 10  -0.370370  -0.714815  -0.103704  -0.225926  -0.433333  -0.607407
# 11  -0.714815  -0.103704  -0.225926  -0.433333  -0.607407  -0.522222
#
#     var1(t-1)   var1(t)
# 7   -0.225926 -0.433333
# 8   -0.433333 -0.607407
# 9   -0.607407 -0.522222
# 10  -0.522222 -0.644444
# 11  -0.644444 -0.344444

# %%
# significa algo así como «567 entradas con vectores de 1×7».
# split into train and test sets
values = reframed.values
n_train_days = 315+289 - (30+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (567, 1, 7) (567,) (30, 1, 7) (30,)

# %%
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
# Veamos cómo se comporta nuestra máquina al cabo de 40 épocas.
EPOCHS=40

model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1, 7)              56
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 64
# Trainable params: 64
# Non-trainable params: 0
# _________________________________________________________________
# Train on 567 samples, validate on 30 samples
# Epoch 1/40
# 567/567 [==============================] - 1s 1ms/step - loss: 0.2500 - mean_squared_error: 0.1011 - val_loss: 0.1971 - val_mean_squared_error: 0.0704
# Epoch 2/40
# 567/567 [==============================] - 0s 185us/step - loss: 0.2089 - mean_squared_error: 0.0737 - val_loss: 0.1865 - val_mean_squared_error: 0.0645
# Epoch 3/40
# 567/567 [==============================] - 0s 178us/step - loss: 0.1992 - mean_squared_error: 0.0687 - val_loss: 0.1751 - val_mean_squared_error: 0.0561
# Epoch 4/40
# 567/567 [==============================] - 0s 162us/step - loss: 0.1925 - mean_squared_error: 0.0654 - val_loss: 0.1713 - val_mean_squared_error: 0.0537
# Epoch 5/40
# 567/567 [==============================] - 0s 183us/step - loss: 0.1885 - mean_squared_error: 0.0633 - val_loss: 0.1669 - val_mean_squared_error: 0.0500
# Epoch 6/40
# 567/567 [==============================] - 0s 155us/step - loss: 0.1854 - mean_squared_error: 0.0616 - val_loss: 0.1635 - val_mean_squared_error: 0.0487
# Epoch 7/40
# 567/567 [==============================] - 0s 155us/step - loss: 0.1823 - mean_squared_error: 0.0610 - val_loss: 0.1593 - val_mean_squared_error: 0.0458
# Epoch 8/40
# 567/567 [==============================] - 0s 157us/step - loss: 0.1797 - mean_squared_error: 0.0595 - val_loss: 0.1569 - val_mean_squared_error: 0.0448
# Epoch 9/40
# 567/567 [==============================] - 0s 144us/step - loss: 0.1782 - mean_squared_error: 0.0588 - val_loss: 0.1564 - val_mean_squared_error: 0.0452
# Epoch 10/40
# 567/567 [==============================] - 0s 142us/step - loss: 0.1767 - mean_squared_error: 0.0586 - val_loss: 0.1538 - val_mean_squared_error: 0.0409
# Epoch 11/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1756 - mean_squared_error: 0.0577 - val_loss: 0.1508 - val_mean_squared_error: 0.0404
# Epoch 12/40
# 567/567 [==============================] - 0s 160us/step - loss: 0.1739 - mean_squared_error: 0.0571 - val_loss: 0.1515 - val_mean_squared_error: 0.0389
# Epoch 13/40
# 567/567 [==============================] - 0s 206us/step - loss: 0.1739 - mean_squared_error: 0.0567 - val_loss: 0.1484 - val_mean_squared_error: 0.0392
# Epoch 14/40
# 567/567 [==============================] - 0s 195us/step - loss: 0.1733 - mean_squared_error: 0.0567 - val_loss: 0.1490 - val_mean_squared_error: 0.0394
# Epoch 15/40
# 567/567 [==============================] - 0s 179us/step - loss: 0.1724 - mean_squared_error: 0.0563 - val_loss: 0.1474 - val_mean_squared_error: 0.0385
# Epoch 16/40
# 567/567 [==============================] - 0s 181us/step - loss: 0.1734 - mean_squared_error: 0.0573 - val_loss: 0.1466 - val_mean_squared_error: 0.0379
# Epoch 17/40
# 567/567 [==============================] - 0s 157us/step - loss: 0.1717 - mean_squared_error: 0.0562 - val_loss: 0.1448 - val_mean_squared_error: 0.0367
# Epoch 18/40
# 567/567 [==============================] - 0s 155us/step - loss: 0.1712 - mean_squared_error: 0.0561 - val_loss: 0.1445 - val_mean_squared_error: 0.0368
# Epoch 19/40
# 567/567 [==============================] - 0s 145us/step - loss: 0.1712 - mean_squared_error: 0.0560 - val_loss: 0.1450 - val_mean_squared_error: 0.0370
# Epoch 20/40
# 567/567 [==============================] - 0s 140us/step - loss: 0.1712 - mean_squared_error: 0.0561 - val_loss: 0.1446 - val_mean_squared_error: 0.0359
# Epoch 21/40
# 567/567 [==============================] - 0s 173us/step - loss: 0.1714 - mean_squared_error: 0.0559 - val_loss: 0.1433 - val_mean_squared_error: 0.0356
# Epoch 22/40
# 567/567 [==============================] - 0s 208us/step - loss: 0.1704 - mean_squared_error: 0.0557 - val_loss: 0.1434 - val_mean_squared_error: 0.0363
# Epoch 23/40
# 567/567 [==============================] - 0s 185us/step - loss: 0.1703 - mean_squared_error: 0.0557 - val_loss: 0.1430 - val_mean_squared_error: 0.0361
# Epoch 24/40
# 567/567 [==============================] - 0s 178us/step - loss: 0.1697 - mean_squared_error: 0.0557 - val_loss: 0.1456 - val_mean_squared_error: 0.0373
# Epoch 25/40
# 567/567 [==============================] - 0s 174us/step - loss: 0.1702 - mean_squared_error: 0.0556 - val_loss: 0.1428 - val_mean_squared_error: 0.0360
# Epoch 26/40
# 567/567 [==============================] - 0s 165us/step - loss: 0.1699 - mean_squared_error: 0.0556 - val_loss: 0.1415 - val_mean_squared_error: 0.0355
# Epoch 27/40
# 567/567 [==============================] - 0s 132us/step - loss: 0.1702 - mean_squared_error: 0.0552 - val_loss: 0.1452 - val_mean_squared_error: 0.0373
# Epoch 28/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.1702 - mean_squared_error: 0.0559 - val_loss: 0.1413 - val_mean_squared_error: 0.0352
# Epoch 29/40
# 567/567 [==============================] - 0s 157us/step - loss: 0.1695 - mean_squared_error: 0.0557 - val_loss: 0.1426 - val_mean_squared_error: 0.0359
# Epoch 30/40
# 567/567 [==============================] - 0s 174us/step - loss: 0.1704 - mean_squared_error: 0.0557 - val_loss: 0.1410 - val_mean_squared_error: 0.0352
# Epoch 31/40
# 567/567 [==============================] - 0s 172us/step - loss: 0.1693 - mean_squared_error: 0.0556 - val_loss: 0.1412 - val_mean_squared_error: 0.0346
# Epoch 32/40
# 567/567 [==============================] - 0s 135us/step - loss: 0.1691 - mean_squared_error: 0.0549 - val_loss: 0.1423 - val_mean_squared_error: 0.0358
# Epoch 33/40
# 567/567 [==============================] - 0s 142us/step - loss: 0.1694 - mean_squared_error: 0.0555 - val_loss: 0.1414 - val_mean_squared_error: 0.0351
# Epoch 34/40
# 567/567 [==============================] - 0s 139us/step - loss: 0.1689 - mean_squared_error: 0.0554 - val_loss: 0.1410 - val_mean_squared_error: 0.0345
# Epoch 35/40
# 567/567 [==============================] - 0s 134us/step - loss: 0.1702 - mean_squared_error: 0.0558 - val_loss: 0.1407 - val_mean_squared_error: 0.0347
# Epoch 36/40
# 567/567 [==============================] - 0s 142us/step - loss: 0.1689 - mean_squared_error: 0.0554 - val_loss: 0.1402 - val_mean_squared_error: 0.0345
# Epoch 37/40
# 567/567 [==============================] - 0s 155us/step - loss: 0.1694 - mean_squared_error: 0.0552 - val_loss: 0.1401 - val_mean_squared_error: 0.0351
# Epoch 38/40
# 567/567 [==============================] - 0s 142us/step - loss: 0.1695 - mean_squared_error: 0.0552 - val_loss: 0.1421 - val_mean_squared_error: 0.0358
# Epoch 39/40
# 567/567 [==============================] - 0s 137us/step - loss: 0.1694 - mean_squared_error: 0.0551 - val_loss: 0.1415 - val_mean_squared_error: 0.0356
# Epoch 40/40
# 567/567 [==============================] - 0s 125us/step - loss: 0.1692 - mean_squared_error: 0.0554 - val_loss: 0.1413 - val_mean_squared_error: 0.0355

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()

# %%
ultimosDias = df['2018-11-16':'2018-11-30']
ultimosDias
# Out:
# fecha
# 2018-11-16    152
# 2018-11-17    111
# 2018-11-19    207
# 2018-11-20    206
# 2018-11-21    183
# 2018-11-22    200
# 2018-11-23    187
# 2018-11-24    189
# 2018-11-25     76
# 2018-11-26    276
# 2018-11-27    220
# 2018-11-28    183
# 2018-11-29    251
# 2018-11-30    189
# Name: unidades, dtype: int64

# %%
values = ultimosDias.values
values = values.astype('float32')
# normalize features
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.drop(reframed.columns[[7]], axis=1, inplace=True)
reframed.head(7)
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7       -0.24      -0.65       0.31       0.30       0.07       0.24
# 8       -0.65       0.31       0.30       0.07       0.24       0.11
# 9        0.31       0.30       0.07       0.24       0.11       0.13
# 10       0.30       0.07       0.24       0.11       0.13      -1.00
# 11       0.07       0.24       0.11       0.13      -1.00       1.00
# 12       0.24       0.11       0.13      -1.00       1.00       0.44
# 13       0.11       0.13      -1.00       1.00       0.44       0.07
#
#     var1(t-1)
# 7        0.11
# 8        0.13
# 9       -1.00
# 10       1.00
# 11       0.44
# 12       0.07
# 13       0.75

# %%
values = reframed.values
x_test = values[6:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
x_test
# Out:
# array([[[ 0.11000001,  0.13      , -1.        ,  1.        ,
#           0.44000006,  0.06999993,  0.75      ]]], dtype=float32)

# %%
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test

results=[]
for i in range(7):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test=agregarNuevoValor(x_test,parcial[0])
# Out:
# [[[ 0.11000001  0.13       -1.          1.          0.44000006
#     0.06999993  0.75      ]]]
# [[[ 0.13       -1.          1.          0.44000006  0.06999993
#     0.75       -0.03744889]]]
# [[[-1.          1.          0.44000006  0.06999993  0.75
#    -0.03744889 -0.50365824]]]
# [[[ 1.          0.44000006  0.06999993  0.75       -0.03744889
#    -0.50365824  0.43663496]]]
# [[[ 0.44000006  0.06999993  0.75       -0.03744889 -0.50365824
#     0.43663496  0.31845507]]]
# [[[ 0.06999993  0.75       -0.03744889 -0.50365824  0.43663496
#     0.31845507 -0.01693732]]]
# [[[ 0.75       -0.03744889 -0.50365824  0.43663496  0.31845507
#    -0.01693732  0.30122426]]]

# %%
adimen = [x for x in results]    
inverted = scaler.inverse_transform(adimen)
inverted
# Out:
# array([[172.25511385],
#        [125.63417835],
#        [219.66349974],
#        [207.84551072],
#        [174.30627102],
#        [206.12242981],
#        [170.47341102]])

# %%
prediccion1SemanaDiciembre = pd.DataFrame(inverted)
prediccion1SemanaDiciembre.columns = ['pronostico']
prediccion1SemanaDiciembre.plot()
prediccion1SemanaDiciembre.to_csv('pronostico.csv')
